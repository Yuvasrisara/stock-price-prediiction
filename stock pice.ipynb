# %%
import pandas as pd
import datetime as dt
from datetime import date
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
import tensorflow as tf

START = "2010-01-01"
TODAY = date.today().strftime("%Y-%m-%d")

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

data = load_data('TCS.NS')
df=data
df.head()

df = df.drop([], axis = 1)
df.head()

plt.figure(figsize=(12, 6))
plt.plot(df['Close'])
plt.title("TCS India Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.grid(True)
plt.show()

df

ma100 = df.Close.rolling(100).mean()
ma100

plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.grid(True)
plt.title('Graph Of Moving Averages Of 100 Days')

ma200 = df.Close.rolling(200).mean()
ma200

plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')
plt.grid(True)
plt.title('Comparision Of 100 Days And 200 Days Moving Averages')

df.shape

train = pd.DataFrame(data[0:int(len(data)*0.70)])
test = pd.DataFrame(data[int(len(data)*0.70): int(len(data))])

print(train.shape)
print(test.shape)

train.head()
test.head()

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

train_close = train.iloc[:, 4:5].values
test_close = test.iloc[:, 4:5].values

data_training_array = scaler.fit_transform(train_close)
data_training_array

x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

x_train.shape

from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences=True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units = 60, activation = 'relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units = 80, activation = 'relu', return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1))

model.summary()

import tensorflow as tf
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])
model.fit(x_train, y_train,epochs = 100)

model.save('keras_model.h5')

test_close.shape

past_100_days = pd.DataFrame(train_close[-100:])
test_df = pd.DataFrame(test_close)
final_df = pd.concat([past_100_days, test_df], ignore_index = True)
final_df.head()

input_data = scaler.fit_transform(final_df)
input_data
input_data.shape

x_test = []
y_test = []
for i in range(100, input_data.shape[0]):
   x_test.append(input_data[i-100: i])
   y_test.append(input_data[i, 0])

x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)

y_pred = model.predict(x_test)

y_pred.shape
y_test
y_pred

scaler.scale_

scale_factor = 1/0.00041967
y_pred = y_pred * scale_factor
y_test = y_test * scale_factor

plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = "Original Price")
plt.plot(y_pred, 'r', label = "Predicted Price")
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
mae_percentage = (mae / np.mean(y_test)) * 100
print("Mean absolute error on test set: {:.2f}%".format(mae_percentage))

from sklearn.metrics import r2_score
actual = y_test
predicted = y_pred
r2 = r2_score(actual, predicted)
print("R2 score:", r2)

fig, ax = plt.subplots()
ax.barh(0, r2, color='skyblue')
ax.set_xlim([-1, 1])
ax.set_yticks([])
ax.set_xlabel('R2 Score')
ax.set_title('R2 Score')
ax.text(r2, 0, f'{r2:.2f}', va='center', color='black')
plt.show()

plt.scatter(actual, predicted)
plt.plot([min(actual), max(actual)], [min(predicted), max(predicted)], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title(f'R2 Score: {r2:.2f}')
plt.show()
# Out:
# /tmp/ipython-input-908932206.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, START, TODAY)
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# (2713, 6)
# (1163, 6)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                   │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 100, 80)        │        45,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 100, 80)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 120)            │        96,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           121 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 33s 304ms/step - loss: 0.0551 - mean_absolute_error: 0.1625
# Epoch 2/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 293ms/step - loss: 0.0050 - mean_absolute_error: 0.0491
# Epoch 3/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 295ms/step - loss: 0.0049 - mean_absolute_error: 0.0464
# Epoch 4/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 24s 292ms/step - loss: 0.0037 - mean_absolute_error: 0.0424
# Epoch 5/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 24s 296ms/step - loss: 0.0040 - mean_absolute_error: 0.0428
# Epoch 6/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 301ms/step - loss: 0.0038 - mean_absolute_error: 0.0416
# Epoch 7/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 38s 259ms/step - loss: 0.0047 - mean_absolute_error: 0.0477
# Epoch 8/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - loss: 0.0036 - mean_absolute_error: 0.0428
# Epoch 9/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 258ms/step - loss: 0.0033 - mean_absolute_error: 0.0390
# Epoch 10/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - loss: 0.0032 - mean_absolute_error: 0.0391
# Epoch 11/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 259ms/step - loss: 0.0031 - mean_absolute_error: 0.0377
# Epoch 12/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - loss: 0.0033 - mean_absolute_error: 0.0397
# Epoch 13/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 260ms/step - loss: 0.0030 - mean_absolute_error: 0.0374
# Epoch 14/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 262ms/step - loss: 0.0027 - mean_absolute_error: 0.0364
# Epoch 15/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 247ms/step - loss: 0.0024 - mean_absolute_error: 0.0336
# Epoch 16/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 24s 294ms/step - loss: 0.0029 - mean_absolute_error: 0.0364
# Epoch 17/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 279ms/step - loss: 0.0026 - mean_absolute_error: 0.0356
# Epoch 18/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 43s 310ms/step - loss: 0.0026 - mean_absolute_error: 0.0348
# Epoch 19/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 42s 325ms/step - loss: 0.0025 - mean_absolute_error: 0.0344
# Epoch 20/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 37s 271ms/step - loss: 0.0023 - mean_absolute_error: 0.0330
# Epoch 21/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 39s 249ms/step - loss: 0.0025 - mean_absolute_error: 0.0337
# Epoch 22/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 261ms/step - loss: 0.0025 - mean_absolute_error: 0.0343
# Epoch 23/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 260ms/step - loss: 0.0021 - mean_absolute_error: 0.0321
# Epoch 24/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 260ms/step - loss: 0.0025 - mean_absolute_error: 0.0361
# Epoch 25/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - loss: 0.0023 - mean_absolute_error: 0.0325
# Epoch 26/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 260ms/step - loss: 0.0020 - mean_absolute_error: 0.0318
# Epoch 27/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 260ms/step - loss: 0.0020 - mean_absolute_error: 0.0311
# Epoch 28/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 259ms/step - loss: 0.0021 - mean_absolute_error: 0.0319
# Epoch 29/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 260ms/step - loss: 0.0021 - mean_absolute_error: 0.0318
# Epoch 30/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 259ms/step - loss: 0.0019 - mean_absolute_error: 0.0308
# Epoch 31/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 245ms/step - loss: 0.0022 - mean_absolute_error: 0.0331
# Epoch 32/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 261ms/step - loss: 0.0019 - mean_absolute_error: 0.0306
# Epoch 33/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 246ms/step - loss: 0.0021 - mean_absolute_error: 0.0322
# Epoch 34/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 259ms/step - loss: 0.0021 - mean_absolute_error: 0.0322
# Epoch 35/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - loss: 0.0022 - mean_absolute_error: 0.0321
# Epoch 36/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 260ms/step - loss: 0.0023 - mean_absolute_error: 0.0333
# Epoch 37/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - loss: 0.0020 - mean_absolute_error: 0.0316
# Epoch 38/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 258ms/step - loss: 0.0021 - mean_absolute_error: 0.0324
# Epoch 39/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 24s 298ms/step - loss: 0.0018 - mean_absolute_error: 0.0297
# Epoch 40/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 24s 297ms/step - loss: 0.0020 - mean_absolute_error: 0.0305
# Epoch 41/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 301ms/step - loss: 0.0021 - mean_absolute_error: 0.0311
# Epoch 42/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 288ms/step - loss: 0.0020 - mean_absolute_error: 0.0312
# Epoch 43/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - loss: 0.0018 - mean_absolute_error: 0.0290
# Epoch 44/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 294ms/step - loss: 0.0019 - mean_absolute_error: 0.0306
# Epoch 45/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 24s 294ms/step - loss: 0.0018 - mean_absolute_error: 0.0304
# Epoch 46/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - loss: 0.0018 - mean_absolute_error: 0.0297
# Epoch 47/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 283ms/step - loss: 0.0022 - mean_absolute_error: 0.0332
# Epoch 48/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 24s 296ms/step - loss: 0.0018 - mean_absolute_error: 0.0303
# Epoch 49/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 295ms/step - loss: 0.0019 - mean_absolute_error: 0.0301
# Epoch 50/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 298ms/step - loss: 0.0018 - mean_absolute_error: 0.0306
# Epoch 51/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 302ms/step - loss: 0.0019 - mean_absolute_error: 0.0316
# Epoch 52/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 24s 293ms/step - loss: 0.0019 - mean_absolute_error: 0.0309
# Epoch 53/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 23s 283ms/step - loss: 0.0018 - mean_absolute_error: 0.0301
# Epoch 54/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 39s 262ms/step - loss: 0.0016 - mean_absolute_error: 0.0280
# Epoch 55/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 248ms/step - loss: 0.0017 - mean_absolute_error: 0.0293
# Epoch 56/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - loss: 0.0019 - mean_absolute_error: 0.0316
# Epoch 57/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 263ms/step - loss: 0.0020 - mean_absolute_error: 0.0323
# Epoch 58/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - loss: 0.0017 - mean_absolute_error: 0.0289
# Epoch 59/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 266ms/step - loss: 0.0016 - mean_absolute_error: 0.0290
# Epoch 60/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 253ms/step - loss: 0.0018 - mean_absolute_error: 0.0299
# Epoch 61/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 42s 266ms/step - loss: 0.0018 - mean_absolute_error: 0.0305
# Epoch 62/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 43s 287ms/step - loss: 0.0017 - mean_absolute_error: 0.0298
# Epoch 63/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 38s 250ms/step - loss: 0.0018 - mean_absolute_error: 0.0303
# Epoch 64/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 42s 263ms/step - loss: 0.0016 - mean_absolute_error: 0.0289
# Epoch 65/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 39s 242ms/step - loss: 0.0021 - mean_absolute_error: 0.0323
# Epoch 66/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 256ms/step - loss: 0.0019 - mean_absolute_error: 0.0307
# Epoch 67/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 261ms/step - loss: 0.0018 - mean_absolute_error: 0.0293
# Epoch 68/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 42s 273ms/step - loss: 0.0018 - mean_absolute_error: 0.0304
# Epoch 69/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - loss: 0.0017 - mean_absolute_error: 0.0293
# Epoch 70/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 249ms/step - loss: 0.0017 - mean_absolute_error: 0.0286
# Epoch 71/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 42s 260ms/step - loss: 0.0017 - mean_absolute_error: 0.0298
# Epoch 72/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 262ms/step - loss: 0.0018 - mean_absolute_error: 0.0310
# Epoch 73/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - loss: 0.0020 - mean_absolute_error: 0.0308
# Epoch 74/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 260ms/step - loss: 0.0016 - mean_absolute_error: 0.0284
# Epoch 75/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 264ms/step - loss: 0.0017 - mean_absolute_error: 0.0291
# Epoch 76/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 247ms/step - loss: 0.0016 - mean_absolute_error: 0.0288
# Epoch 77/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 256ms/step - loss: 0.0017 - mean_absolute_error: 0.0292
# Epoch 78/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 242ms/step - loss: 0.0017 - mean_absolute_error: 0.0292
# Epoch 79/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 23s 271ms/step - loss: 0.0018 - mean_absolute_error: 0.0296
# Epoch 80/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 257ms/step - loss: 0.0018 - mean_absolute_error: 0.0306
# Epoch 81/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 250ms/step - loss: 0.0018 - mean_absolute_error: 0.0301
# Epoch 82/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 258ms/step - loss: 0.0017 - mean_absolute_error: 0.0286
# Epoch 83/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 260ms/step - loss: 0.0017 - mean_absolute_error: 0.0301
# Epoch 84/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - loss: 0.0016 - mean_absolute_error: 0.0287
# Epoch 85/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 258ms/step - loss: 0.0018 - mean_absolute_error: 0.0303
# Epoch 86/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 41s 257ms/step - loss: 0.0016 - mean_absolute_error: 0.0289
# Epoch 87/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 43s 278ms/step - loss: 0.0018 - mean_absolute_error: 0.0298
# Epoch 88/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 38s 247ms/step - loss: 0.0016 - mean_absolute_error: 0.0282
# Epoch 89/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 259ms/step - loss: 0.0016 - mean_absolute_error: 0.0285
# Epoch 90/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 247ms/step - loss: 0.0016 - mean_absolute_error: 0.0286
# Epoch 91/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 255ms/step - loss: 0.0017 - mean_absolute_error: 0.0298
# Epoch 92/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 260ms/step - loss: 0.0017 - mean_absolute_error: 0.0280
# Epoch 93/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - loss: 0.0016 - mean_absolute_error: 0.0284
# Epoch 94/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 259ms/step - loss: 0.0016 - mean_absolute_error: 0.0280
# Epoch 95/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - loss: 0.0015 - mean_absolute_error: 0.0273
# Epoch 96/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 256ms/step - loss: 0.0019 - mean_absolute_error: 0.0305
# Epoch 97/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 273ms/step - loss: 0.0016 - mean_absolute_error: 0.0269
# Epoch 98/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 245ms/step - loss: 0.0016 - mean_absolute_error: 0.0284
# Epoch 99/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 254ms/step - loss: 0.0018 - mean_absolute_error: 0.0298
# Epoch 100/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 260ms/step - loss: 0.0017 - mean_absolute_error: 0.0286
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# (1163, 100, 1)
# (1163,)
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step
# Mean absolute error on test set: 8.96%
# R2 score: 0.8717517188275994
